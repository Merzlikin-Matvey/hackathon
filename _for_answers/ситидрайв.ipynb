# %%
# 5 КАРМАНОВ

# %%
import pandas as pd
import numpy as np
import prophet
from make_series import *
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
import warnings
from statsmodels.tsa.arima.model import ARIMA


warnings.filterwarnings("ignore")
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
# Соберем нужные данные
df = pd.read_excel('../data/normalized_data.xlsx')
series = make_series(df,'Лимузины и таксиЛимузины и такси', is_exponential_smoothing=True)
series_diff = [0.4]
for i in range(1, len(series)):
    series_diff.append(series[i] / series[i-1])

dates = get_all_dates()

# Сделаем из 2 столбцов датафрейм
df = pd.DataFrame({'ds': dates, 'y': series})


df['ds'] = pd.to_datetime(df['ds'])

# Сделаем график series
plt.figure(figsize=(20, 10))
plt.plot(df['ds'], df['y'])
plt.show()

# %%
# Построим график автолкорреляции на всех данных
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(np.array(series))

# %%
test_stationarity(series)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.800868
# p-value                          0.002898
# #Lags Used                       0.000000
# Number of Observations Used    395.000000
# Critical Value (1%)             -3.447014
# Critical Value (5%)             -2.868885
# Critical Value (10%)            -2.570683
# dtype: float64

# %%
# Создадим модель prophet
model = prophet.Prophet()
# Добавим сезонность
model.add_seasonality(name='monthly', period=300.                        , fourier_order=50)
model.fit(df)
# Out:
# 14:49:54 - cmdstanpy - INFO - Chain [1] start processing
# 14:49:54 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Построим график реальных значений и предсказанных на тренировочной выборке
future = model.make_future_dataframe(periods=28, freq='D')
forecast = model.predict(future)
model.plot(forecast)

# %%
# Предскажем данные еще на месяц
future = model.make_future_dataframe(periods=60, freq='D')
forecast = model.predict(future)
model.plot(forecast)

# %%
# Найдем MAE и MAPE
y_true = series
y_pred = forecast['yhat'][:len(series)]
mae = mean_absolute_error(y_true, y_pred)
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
print(f'MAE: {mae}')
print(f'MAPE: {mape}')
# Out:
# MAE: 0.050345092789836864
# MAPE: 216044.94401258952
