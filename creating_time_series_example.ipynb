# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from make_series import make_series

warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('data/normalized_data.xlsx')

# %%
series = make_series(df, 'Бакалейные магазины, супермаркеты', True)

# Построим график series
plt.figure(figsize=(15, 7))
plt.plot(series)
plt.show()

# %%
series = make_series(df, 'Бакалейные магазины, супермаркеты', True, 1)

# Построим график series
plt.figure(figsize=(15, 7))
plt.plot(series)
plt.show()
