# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from make_series import *

warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('data/normalized_data.xlsx')

# %%
series = make_series(df, 'Фастфуд',is_exponential_smoothing=True, alpha=0.1)
series_diff = []
for i in range(1, len(series)):
    series_diff.append(series[i] - series[i-1])


# Построим график series
plt.figure(figsize=(15, 7))
plt.plot(series_diff)
plt.show()

# %%
test_stationarity(series_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.601118
# p-value                          0.000001
# #Lags Used                       6.000000
# Number of Observations Used    388.000000
# Critical Value (1%)             -3.447317
# Critical Value (5%)             -2.869018
# Critical Value (10%)            -2.570754
# dtype: float64
